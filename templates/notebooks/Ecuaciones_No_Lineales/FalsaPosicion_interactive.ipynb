# %% [markdown]
# <a href="https://colab.research.google.com/github/jugernaut/Numerico2021/blob/master/02_EcuacionesNoLineales/FalsaPosicion_interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import gutils as vis
# %matplotlib inline

# funcion a graficar y de la cual se busca la raiz
def f(x):
  return (x**2)-1

x = np.arange(-0.25, 2, 0.1)
fx = [f(i) for i in x]
raiz,sucesion = vis.falsaPosicion(f,0.001,1000,-0.5,2)

par = [{'title':'$f(x)$', 
        'xlabel':'$x$',
        'ylabel':'$y$'}]
graf = vis.planoCartesiano(par=par)
#funcion a grficar
graf.plot(x=x,y=fx)
#ejes
graf.plot(x = [-0.25, 2], y = [0, 0], par={'ls':'-', 'lw':1, 'color':'black'})
graf.plot(x = [0, 0], y = [-1, 2.5], par={'ls':'-', 'lw':1, 'color':'black'})

#intersecciones
graf.plot(x = [-0.5, 2], y = [f(-0.5), f(2)], par={'ls':'-', 'lw':1, 'color':'black'})
graf.plot(x = [-0.5, 2], y = [-2, f(2)], par={'ls':'-', 'lw':1, 'color':'black'})
graf.plot(x = [-0.5, 2], y = [-4.5, f(2)], par={'ls':'-', 'lw':1, 'color':'black'})

# iteracion 1
graf.annotate(par={'s':'$x_1$ = '+str(sucesion[0]), 'xy':(sucesion[0], 0), 'xycoords':'data',
                   'xytext':(-0.25,1), 'fontsize':12,
                   'textcoords':'data', 'ha':'center', 'va':'bottom',
                   'bbox':{'boxstyle':'round','pad':0.4, 'fc':'blue', 'alpha':0.25},
                   'arrowprops':{'arrowstyle':'->', 'connectionstyle':'arc3,rad=0.5', 'color':'black'}}) 
# iteracion 2
graf.annotate(par={'s':'$x_2$ = '+str(sucesion[1]), 'xy':(sucesion[1], 0), 'xycoords':'data',
                   'xytext':(0.5,-0.5), 'fontsize':12,
                   'textcoords':'data', 'ha':'center', 'va':'bottom',
                   'bbox':{'boxstyle':'round','pad':0.4, 'fc':'blue', 'alpha':0.25},
                   'arrowprops':{'arrowstyle':'->', 'connectionstyle':'arc3,rad=0.5', 'color':'black'}}) 
# iteracion n
graf.annotate(par={'s':'$x_n$ = '+str(sucesion[-3]), 'xy':(sucesion[-3], 0), 'xycoords':'data',
                   'xytext':(1.25,-1.0), 'fontsize':12,
                   'textcoords':'data', 'ha':'center', 'va':'bottom',
                   'bbox':{'boxstyle':'round','pad':0.4, 'fc':'blue', 'alpha':0.25},
                   'arrowprops':{'arrowstyle':'->', 'connectionstyle':'arc3,rad=0.5', 'color':'black'}}) 
# raiz
graf.scatter(x=[raiz],y=[0.],par={'c':'red','marker':'o','s':75, 'zorder':5})
graf.annotate(par={'s':'La raíz de f es en x = '+str(raiz), 'xy':(raiz, 0), 'xytext':(-50,85), 'fontsize':15,
            'textcoords':'offset points', 'ha':'center', 'va':'bottom',
            'bbox':{'boxstyle':'round','pad':0.2, 'fc':'yellow', 'alpha':0.3},
            'arrowprops':{'arrowstyle':'->', 'connectionstyle':'arc3,rad=0.5', 
                           'color':'black'}})

graf.show()
# Out:
# C:\Users\ferna\OneDrive\Escritorio\SS\01_Funciones\SS_provisional\EcuacionesNoLineales\gutils.py:195: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   return self.__ax[n-1].annotate(**par)
